# %% [markdown]
# #Ex.No.1 Download nltk and packages. Use it to print the tokens in a document and the the sentences from it

# %% [markdown]
# ##AIM:
# To demonstrateb the use of the Natural Language Toolkit(NLTJ) library in python for tokenizing a given text document into words (tokens) and sentences.

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %% [markdown]
# ### Tokenize words and sentences

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
text = """My name is Thangaraj. Currently I am pursuing ME - CSE in AI/ML.
Tomorrow I have the semester practical examination of Natural Language Processing"""

# %%
words = word_tokenize(text)
# Out:
# ['My', 'name', 'is', 'Thangaraj', '.', 'Currently', 'I', 'am', 'pursuing', 'ME', '-', 'CSE', 'in', 'AI/ML', '.', 'Tomorrow', 'I', 'have', 'the', 'semester', 'practical', 'examination', 'of', 'Natural', 'Language', 'Processing']

# %%
sentence = sent_tokenize(text)
# Out:
# ['My name is Thangaraj.', 'Currently I am pursuing ME - CSE in AI/ML.', 'Tomorrow I have the semester practical examination of Natural Language Processing']

# %% [markdown]
# ### Output

# %%
print("Tokenize words are :-\n" , words)
print("\nTokenize sentences are :-\n", sentence)
# Out:
# Tokenize words are :-
#  ['My', 'name', 'is', 'Thangaraj', '.', 'Currently', 'I', 'am', 'pursuing', 'ME', '-', 'CSE', 'in', 'AI/ML', '.', 'Tomorrow', 'I', 'have', 'the', 'semester', 'practical', 'examination', 'of', 'Natural', 'Language', 'Processing']
#
# Tokenize sentences are :-
#  ['My name is Thangaraj.', 'Currently I am pursuing ME - CSE in AI/ML.', 'Tomorrow I have the semester practical examination of Natural Language Processing']

# %% [markdown]
# ###Result:
#     Result:
# Thus the NLTK library was successfully used to tokenize the document into words and sentences.
